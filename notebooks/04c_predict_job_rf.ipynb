# %%
DF_PATH       = "../data/processed/2_cleaned_data.pkl"

ROLE_COLS      = ['DevType']
TECH_COLS      = ['LanguageHaveWorkedWith',
                  'DatabaseHaveWorkedWith',
                  'PlatformHaveWorkedWith',
                  'WebframeHaveWorkedWith',
                  'MiscTechHaveWorkedWith',
                  'ToolsTechHaveWorkedWith',
                  'NEWCollabToolsHaveWorkedWith']

MLFLOW_TRACKING_URI = '../models/mlruns'
MLFLOW_EXPERIMENT_NAME = "skills_jobs_stackoverflow"

LOG_PATH = "../models/temp/"
LOG_DATA_PKL    =  "data_rf.pkl"
LOG_MODEL_PKL   =  "model_rf.pkl"
LOG_METRICS_PKL =  "metrics_rf.pkl"

# %%
# Load packages
import pandas as pd 
import numpy as np
import logging
import pickle
import random
import plotly 
import os
from pathlib import Path

import mlflow
from mlflow.tracking import MlflowClient

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline, FeatureUnion
from sklearn.feature_selection import VarianceThreshold
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

from sklearn import metrics
from sklearn.metrics import auc, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score

from sklearn.decomposition import PCA, KernelPCA

from sklearn import tree
from sklearn.linear_model import LogisticRegression

from matplotlib import pyplot as plt

# %%
df = pd.read_pickle(DF_PATH)

# %%
df['DevType'].sum(axis=0)
# Out:
# Academic researcher                               581
# Data or business analyst                          669
# Data scientist or machine learning specialist     799
# Database administrator                            296
# DevOps specialist                                 677
# Developer, QA or test                             493
# Developer, back-end                              5503
# Developer, desktop or enterprise applications    1671
# Developer, embedded applications or devices       795
# Developer, front-end                             2890
# Developer, full-stack                            5578
# Developer, game or graphics                       342
# Developer, mobile                                1859
# Engineer, data                                    483
# Scientist                                         292
# System administrator                              440
# dtype: int64

# %%
roles = df['DevType'].columns.tolist()
sample_size = 500
final_sample = []

for role in roles:
    df_role = df[df[('DevType',role)] == 1]
    
    if len(df_role) < sample_size:
        df_role = df_role.sample(sample_size, replace = True,random_state=42)
    
        
    else:
        df_role = df_role.sample(sample_size, replace = True)
        
    final_sample.append(df_role)

# %%
final_sample = pd.concat(final_sample)
final_sample['DevType'].sum()
# Out:
# Academic researcher                               810
# Data or business analyst                          772
# Data scientist or machine learning specialist     863
# Database administrator                            587
# DevOps specialist                                 712
# Developer, QA or test                             596
# Developer, back-end                              1771
# Developer, desktop or enterprise applications     887
# Developer, embedded applications or devices       660
# Developer, front-end                              855
# Developer, full-stack                            1413
# Developer, game or graphics                       566
# Developer, mobile                                 798
# Engineer, data                                    608
# Scientist                                         657
# System administrator                              653
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(final_sample.drop(ROLE_COLS, axis=1),final_sample[ROLE_COLS], test_size=0.2, random_state=42)
# Out:
# C:\Users\Sameh\AppData\Local\Temp\ipykernel_14056\3904673217.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X_train, X_test, y_train, y_test = train_test_split(final_sample.drop(ROLE_COLS, axis=1),final_sample[ROLE_COLS], test_size=0.2, random_state=42)

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client = MlflowClient()
mlflow.set_experiment(MLFLOW_EXPERIMENT_NAME)
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)

# %% [markdown]
# ## Random Forest

# %%
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)
pred = pd.DataFrame(clf.predict(X_test), columns=y_test.columns)

# %%
table = {}
for role in roles:
    
    mat = metrics.accuracy_score(y_test[('DevType',role)], pred[('DevType',role)])
    per = metrics.precision_score(y_test[('DevType',role)], pred[('DevType',role)])
    recal = metrics.recall_score(y_test[('DevType',role)], pred[('DevType',role)])
    f1= metrics.f1_score(y_test[('DevType',role)], pred[('DevType',role)])
    table[role] = [mat, per, recal, f1]
    
table = pd.DataFrame(table, index = ['Accuracy', 'Precision', 'Recall', 'F1']).sort_values(by='Precision', axis=1, ascending=False)
table.T
# Out:
#                                                Accuracy  Precision    Recall
# System administrator                           0.970000   0.961165  0.692308  \
# Data scientist or machine learning specialist  0.965000   0.954545  0.715909
# Engineer, data                                 0.971250   0.944444  0.674603
# Developer, mobile                              0.971250   0.941667  0.743421
# Scientist                                      0.980625   0.926606  0.814516
# DevOps specialist                              0.972500   0.922414  0.753521
# Data or business analyst                       0.967500   0.920000  0.732484
# Developer, game or graphics                    0.978125   0.884211  0.777778
# Academic researcher                            0.958125   0.883333  0.666667
# Database administrator                         0.970625   0.875000  0.728000
# Developer, back-end                            0.874375   0.868778  0.527473
# Developer, QA or test                          0.964375   0.863636  0.628099
# Developer, front-end                           0.935625   0.842593  0.514124
# Developer, full-stack                          0.900625   0.815385  0.563830
# Developer, desktop or enterprise applications  0.936250   0.810127  0.423841
# Developer, embedded applications or devices    0.958125   0.798165  0.659091
#
#                                                      F1
# System administrator                           0.804878
# Data scientist or machine learning specialist  0.818182
# Engineer, data                                 0.787037
# Developer, mobile                              0.830882
# Scientist                                      0.866953
# DevOps specialist                              0.829457
# Data or business analyst                       0.815603
# Developer, game or graphics                    0.827586
# Academic researcher                            0.759857
# Database administrator                         0.794760
# Developer, back-end                            0.656410
# Developer, QA or test                          0.727273
# Developer, front-end                           0.638596
# Developer, full-stack                          0.666667
# Developer, desktop or enterprise applications  0.556522
# Developer, embedded applications or devices    0.721992

# %%
table.T['Precision'].mean()
# Out:
# 0.8882542714743562

# %%
meta_data = {
    'data_path':DF_PATH,
    'traing_index':X_train.index.to_list(),
    'test_index':X_test.index.to_list(),
    'feature_name':X_train.columns.to_list(),
    'tareget_name':y_train.columns.to_list(),
}

with open(os.path.join(LOG_PATH,LOG_DATA_PKL),'wb') as f:
    pickle.dump(meta_data,f)

# %%
model ={
    'model_description':clf.__class__.__name__,
    'model_details':str(clf),
    'model':clf,
}

with open(os.path.join(LOG_PATH,LOG_MODEL_PKL),'wb') as f:
    pickle.dump(model,f)

# %%
performance = {
    'accuracy':table.T['Accuracy'].mean(),
    'percision':table.T['Precision'].mean(),
    'recall':table.T['Recall'].mean(),
    'f1':table.T['F1'].mean(),
}

with open(os.path.join(LOG_PATH,LOG_METRICS_PKL),'wb') as f:
    pickle.dump(performance,f)

# %%
with mlflow.start_run(experiment_id=exp.experiment_id, run_name=model['model_description']):
    
    mlflow.log_param("model_description", model['model_description'])
    mlflow.log_param("model_details", model['model_details'])
    
    mlflow.log_metric("accuracy", performance['accuracy'])
    mlflow.log_metric("percision", performance['percision'])
    mlflow.log_metric("recall", performance['recall'])
    mlflow.log_metric("f1", performance['f1'])
    
    mlflow.log_artifact(os.path.join(LOG_PATH,LOG_DATA_PKL))
    mlflow.log_artifact(os.path.join(LOG_PATH,LOG_MODEL_PKL))
    mlflow.log_artifact(os.path.join(LOG_PATH,LOG_METRICS_PKL))

# %% [markdown]
# ## Random Frorest + PCA + RBF

# %%
clf = make_pipeline(StandardScaler(),PCA(n_components=0.95) ,RandomForestClassifier(random_state=42))
clf.fit(X_train, y_train)
pred = pd.DataFrame(clf.predict(X_test), columns=y_test.columns)

# %%
table = {}
for role in roles:
    
    mat = metrics.accuracy_score(y_test[('DevType',role)], pred[('DevType',role)])
    per = metrics.precision_score(y_test[('DevType',role)], pred[('DevType',role)])
    recal = metrics.recall_score(y_test[('DevType',role)], pred[('DevType',role)])
    f1= metrics.f1_score(y_test[('DevType',role)], pred[('DevType',role)])
    table[role] = [mat, per, recal, f1]
    
table = pd.DataFrame(table, index = ['Accuracy', 'Precision', 'Recall', 'F1']).sort_values(by='Precision', axis=1, ascending=False)
table.T
# Out:
#                                                Accuracy  Precision    Recall
# System administrator                           0.968125   0.979167  0.657343  \
# DevOps specialist                              0.970625   0.970297  0.690141
# Data scientist or machine learning specialist  0.959375   0.966387  0.653409
# Developer, game or graphics                    0.980625   0.963855  0.740741
# Developer, mobile                              0.965625   0.961905  0.664474
# Engineer, data                                 0.970625   0.943820  0.666667
# Data or business analyst                       0.969375   0.942623  0.732484
# Scientist                                      0.981250   0.935185  0.814516
# Developer, QA or test                          0.968750   0.927711  0.636364
# Database administrator                         0.973750   0.919192  0.728000
# Developer, front-end                           0.934375   0.900000  0.457627
# Developer, back-end                            0.872500   0.892157  0.500000
# Academic researcher                            0.957500   0.882353  0.660377
# Developer, desktop or enterprise applications  0.939375   0.875000  0.417219
# Developer, full-stack                          0.897500   0.859756  0.500000
# Developer, embedded applications or devices    0.960625   0.848485  0.636364
#
#                                                      F1
# System administrator                           0.786611
# DevOps specialist                              0.806584
# Data scientist or machine learning specialist  0.779661
# Developer, game or graphics                    0.837696
# Developer, mobile                              0.785992
# Engineer, data                                 0.781395
# Data or business analyst                       0.824373
# Scientist                                      0.870690
# Developer, QA or test                          0.754902
# Database administrator                         0.812500
# Developer, front-end                           0.606742
# Developer, back-end                            0.640845
# Academic researcher                            0.755396
# Developer, desktop or enterprise applications  0.565022
# Developer, full-stack                          0.632287
# Developer, embedded applications or devices    0.727273

# %%
table.T['Precision'].mean()
# Out:
# 0.9229932692399849

# %%
meta_data = {
    'data_path':DF_PATH,
    'traing_index':X_train.index.to_list(),
    'test_index':X_test.index.to_list(),
    'feature_name':X_train.columns.droplevel(0).to_list(),
    'tareget_name':y_train.columns.droplevel(0).to_list(),
}

with open(os.path.join(LOG_PATH,LOG_DATA_PKL),'wb') as f:
    pickle.dump(meta_data,f)

# %%
model ={
    'model_description':clf.__class__.__name__,
    'model_details':str(clf),
    'model':clf,
}

with open(os.path.join(LOG_PATH,LOG_MODEL_PKL),'wb') as f:
    pickle.dump(model,f)

# %%
performance = {
    'accuracy':table.T['Accuracy'].mean(),
    'percision':table.T['Precision'].mean(),
    'recall':table.T['Recall'].mean(),
    'f1':table.T['F1'].mean(),
}

with open(os.path.join(LOG_PATH,LOG_METRICS_PKL),'wb') as f:
    pickle.dump(performance,f)

# %%
with mlflow.start_run(experiment_id=exp.experiment_id, run_name=model['model_description']):
    
    mlflow.log_param("model_description", model['model_description'])
    mlflow.log_param("model_details", model['model_details'])
    
    mlflow.log_metric("accuracy", performance['accuracy'])
    mlflow.log_metric("percision", performance['percision'])
    mlflow.log_metric("recall", performance['recall'])
    mlflow.log_metric("f1", performance['f1'])
    
    mlflow.log_artifact(os.path.join(LOG_PATH,LOG_DATA_PKL))
    mlflow.log_artifact(os.path.join(LOG_PATH,LOG_MODEL_PKL))
    mlflow.log_artifact(os.path.join(LOG_PATH,LOG_METRICS_PKL))

# %% [markdown]
# ## Hyper parameter tuning

# %%
clf = make_pipeline(StandardScaler(),PCA() ,RandomForestClassifier(random_state=42))

# %%
params ={
    'pca__n_components':[0.95,0.99,0.999],
    'randomforestclassifier__n_estimators':[100,200,300],
    'randomforestclassifier__max_depth':[5,10,15],
}

# %%
hpt_clf = GridSearchCV(clf, params, cv=5, scoring='precision_macro', n_jobs=-1)
hpt_clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('pca', PCA()),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'pca__n_components': [0.95, 0.99, 0.999],
#                          'randomforestclassifier__max_depth': [5, 10, 15],
#                          'randomforestclassifier__n_estimators': [100, 200,
#                                                                   300]},
#              scoring='precision_macro')

# %%
clf =hpt_clf.best_estimator_

# %%
clf.fit(X_train, y_train)
pred = pd.DataFrame(clf.predict(X_test), columns = y_test.columns)

# %%
table = {}
for role in roles:
    
    mat = metrics.accuracy_score(y_test[('DevType',role)], pred[('DevType',role)])
    per = metrics.precision_score(y_test[('DevType',role)], pred[('DevType',role)])
    recal = metrics.recall_score(y_test[('DevType',role)], pred[('DevType',role)])
    f1= metrics.f1_score(y_test[('DevType',role)], pred[('DevType',role)])
    table[role] = [mat, per, recal, f1]
    
table = pd.DataFrame(table, index = ['Accuracy', 'Precision', 'Recall', 'F1']).sort_values(by='Precision', axis=1, ascending=False)
table.T
# Out:
#                                                Accuracy  Precision    Recall
# System administrator                           0.958125   1.000000  0.531469  \
# Developer, QA or test                          0.955625   0.980769  0.421488
# DevOps specialist                              0.965000   0.977778  0.619718
# Data scientist or machine learning specialist  0.954375   0.972477  0.602273
# Developer, mobile                              0.963750   0.970000  0.638158
# Developer, game or graphics                    0.978750   0.962500  0.712963
# Data or business analyst                       0.962500   0.953271  0.649682
# Engineer, data                                 0.962500   0.945946  0.555556
# Developer, desktop or enterprise applications  0.931250   0.936170  0.291391
# Database administrator                         0.969375   0.931818  0.656000
# Academic researcher                            0.947500   0.931034  0.509434
# Scientist                                      0.973750   0.927083  0.717742
# Developer, back-end                            0.865625   0.920904  0.447802
# Developer, front-end                           0.929375   0.900000  0.406780
# Developer, full-stack                          0.895625   0.891156  0.464539
# Developer, embedded applications or devices    0.953750   0.815217  0.568182
#
#                                                      F1
# System administrator                           0.694064
# Developer, QA or test                          0.589595
# DevOps specialist                              0.758621
# Data scientist or machine learning specialist  0.743860
# Developer, mobile                              0.769841
# Developer, game or graphics                    0.819149
# Data or business analyst                       0.772727
# Engineer, data                                 0.700000
# Developer, desktop or enterprise applications  0.444444
# Database administrator                         0.769953
# Academic researcher                            0.658537
# Scientist                                      0.809091
# Developer, back-end                            0.602588
# Developer, front-end                           0.560311
# Developer, full-stack                          0.610723
# Developer, embedded applications or devices    0.669643

# %%
table.T['Precision'].mean()
# Out:
# 0.938507816632391

# %%
meta_data = {
    'data_path':DF_PATH,
    'traing_index':X_train.index.to_list(),
    'test_index':X_test.index.to_list(),
    'feature_name':X_train.columns.droplevel(0).to_list(),
    'tareget_name':y_train.columns.droplevel(0).to_list(),
}

with open(os.path.join(LOG_PATH,LOG_DATA_PKL),'wb') as f:
    pickle.dump(meta_data,f)

# %%
model ={
    'model_description':'RandomForestClassifier with PCA',
    'model_details':str(clf),
    'model':clf,
}

with open(os.path.join(LOG_PATH,LOG_MODEL_PKL),'wb') as f:
    pickle.dump(model,f)

# %%
performance = {
    'accuracy':table.T['Accuracy'].mean(),
    'percision':table.T['Precision'].mean(),
    'recall':table.T['Recall'].mean(),
    'f1':table.T['F1'].mean(),
}

with open(os.path.join(LOG_PATH,LOG_METRICS_PKL),'wb') as f:
    pickle.dump(performance,f)

# %%
with mlflow.start_run(experiment_id=exp.experiment_id, run_name=model['model_description']):
    
    mlflow.log_param("model_description", model['model_description'])
    mlflow.log_param("model_details", model['model_details'])
    
    mlflow.log_metric("accuracy", performance['accuracy'])
    mlflow.log_metric("percision", performance['percision'])
    mlflow.log_metric("recall", performance['recall'])
    mlflow.log_metric("f1", performance['f1'])
    
    mlflow.log_artifact(os.path.join(LOG_PATH,LOG_DATA_PKL))
    mlflow.log_artifact(os.path.join(LOG_PATH,LOG_MODEL_PKL))
    mlflow.log_artifact(os.path.join(LOG_PATH,LOG_METRICS_PKL))

# %%
runs = mlflow.search_runs([exp.experiment_id])
runs
# Out:
#                              run_id       experiment_id    status
# 0  a6a1acf9579f4b858116fa024bff1619  241658575313021916  FINISHED  \
# 1  ce9c69fc63d541059a1edbdd9130ba77  241658575313021916  FINISHED
# 2  4f106e0e9c8845369bb40c9f2c618d71  241658575313021916  FINISHED
# 3  77264420ba6343909c955b6a0686d10b  241658575313021916  FINISHED
#
#                                         artifact_uri
# 0  file:///g:/workspace/e2e_ml_project/notebooks/...  \
# 1  file:///g:/workspace/e2e_ml_project/notebooks/...
# 2  file:///g:/workspace/e2e_ml_project/notebooks/...
# 3  file:///g:/workspace/e2e_ml_project/notebooks/...
#
#                         start_time                         end_time
# 0 2023-08-05 13:37:06.684000+00:00 2023-08-05 13:37:10.182000+00:00  \
# 1 2023-08-05 13:11:28.482000+00:00 2023-08-05 13:11:30.350000+00:00
# 2 2023-08-05 13:11:04.796000+00:00 2023-08-05 13:11:10.010000+00:00
# 3 2023-08-05 13:10:18.401000+00:00 2023-08-05 13:10:18.787000+00:00
#
#    metrics.accuracy  metrics.recall  metrics.percision  metrics.f1
# 0          0.947930        0.549573           0.938508    0.685822  \
# 1          0.954375        0.634733           0.922993    0.747998
# 2          0.954648        0.663479           0.888254    0.756416
# 3          0.912031        0.289507           0.665216    0.375621
#
#                   params.model_description
# 0          RandomForestClassifier with PCA  \
# 1                                 Pipeline
# 2                   RandomForestClassifier
# 3  Baseline model with Logistic Regression
#
#                                 params.model_details
# 0  Pipeline(steps=[('standardscaler', StandardSca...  \
# 1  Pipeline(steps=[('standardscaler', StandardSca...
# 2            RandomForestClassifier(random_state=42)
# 3  Pipeline(steps=[('standardscaler', StandardSca...
#
#                              tags.mlflow.source.name
# 0  c:\Users\Sameh\anaconda3\envs\e2e_env\lib\site...  \
# 1  c:\Users\Sameh\anaconda3\envs\e2e_env\lib\site...
# 2  c:\Users\Sameh\anaconda3\envs\e2e_env\lib\site...
# 3  c:\Users\Sameh\anaconda3\envs\e2e_env\lib\site...
#
#                        tags.mlflow.runName tags.mlflow.user
# 0          RandomForestClassifier with PCA            Sameh  \
# 1                                 Pipeline            Sameh
# 2                   RandomForestClassifier            Sameh
# 3  Baseline model with Logistic Regression            Sameh
#
#   tags.mlflow.source.type
# 0                   LOCAL
# 1                   LOCAL
# 2                   LOCAL
# 3                   LOCAL
